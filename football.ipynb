# %% [markdown]
# <a href="https://colab.research.google.com/github/Kennethfargose/Sports-Analytics-/blob/main/football.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df= pd.read_csv('/content/sportsref_download(1).csv',header=None)

# %%
new_header = df.iloc[0] #grab the first row for the header
df = df[1:] #take the data less the header row
df.columns = new_header

# %%
df
# Out:
# 1     Rk                Player  Nation    Pos          Squad     Age  Born  \
# 2      1            Luis Abram  pe PER     DF        Granada  25-355  1996
# 3      2          Marcos Acuña  ar ARG     DF        Sevilla  30-112  1991
# 4      3  Martin Agirregabiria  es ESP     DF         Alavés  25-283  1996
# 5      4    Julen Agirrezabala  es ESP     GK  Athletic Club  21-053  2000
# 6      5         Sergio Agüero  ar ARG     FW      Barcelona  33-260  1988
# ..   ...                   ...     ...    ...            ...     ...   ...
# 496  495        Manuel Sánchez  es ESP     DF        Osasuna  21-177  2000
# 497  496         Oier Sanjurjo  es ESP     MF        Osasuna  35-268  1986
# 498  497         Sergio Santos  es ESP     DF    Real Madrid  21-045  2001
# 499  498           Alvaro Sanz  es ESP  MF,FW      Barcelona  21-003  2001
# 500  499   Joan Sastre Vanrell  es ESP     DF       Mallorca  24-293  1997
#
# ...

# %%
df1 = df[df["Pos"].str.contains("GK") == False]

# %%
df1.info
# Out:
# <bound method DataFrame.info of 1     Rk                Player  Nation Pos        Squad     Age  Born   90s  \
# 2      1            Luis Abram  pe PER  DF      Granada  25-355  1996   6.2
# 3      2          Marcos Acuña  ar ARG  DF      Sevilla  30-112  1991  16.6
# 4      3  Martin Agirregabiria  es ESP  DF       Alavés  25-283  1996  16.2
# 8      7          Joseph Aidoo  gh GHA  DF   Celta Vigo  26-141  1995  15.3
# 9      8          Carlos Akapo  gq EQG  DF        Cádiz  28-342  1993   9.6
# ..   ...                   ...     ...  ..          ...     ...   ...   ...
# 489  488       Youssouf Sabaly  sn SEN  DF        Betis  28-349  1993   1.0
# 494  493        Germán Sánchez  es ESP  DF      Granada  35-109  1986  15.4
# 496  495        Manuel Sánchez  es ESP  DF      Osasuna  21-177  2000  16.1
# 498  497         Sergio Santos  es ESP  DF  Real Madrid  21-045  2001   0.1
# 500  499   Joan Sastre Vanrell  es ESP  DF     Mallorca  24-293  1997   2.9
#
# ...

# %%
df1 = df1[df1["Pos"].str.contains("MF") == False]

# %%
df1
# Out:
# 1     Rk                Player  Nation Pos           Squad     Age  Born  \
# 2      1            Luis Abram  pe PER  DF         Granada  25-355  1996
# 3      2          Marcos Acuña  ar ARG  DF         Sevilla  30-112  1991
# 4      3  Martin Agirregabiria  es ESP  DF          Alavés  25-283  1996
# 6      5         Sergio Agüero  ar ARG  FW       Barcelona  33-260  1988
# 7      6        Álvaro Aguirre  es ESP  FW  Rayo Vallecano  22-014  2000
# ..   ...                   ...     ...  ..             ...     ...   ...
# 492  491          Oihan Sancet  es ESP  FW   Athletic Club  21-298  2000
# 494  493        Germán Sánchez  es ESP  DF         Granada  35-109  1986
# 496  495        Manuel Sánchez  es ESP  DF         Osasuna  21-177  2000
# 498  497         Sergio Santos  es ESP  DF     Real Madrid  21-045  2001
# 500  499   Joan Sastre Vanrell  es ESP  DF        Mallorca  24-293  1997
#
# 1     90s   Att  Live  ... Right Head   TI Other   Cmp Off Out Int Blocks  \
# ...

# %%
df1 = df1[df1["Pos"].str.contains("FW") == False]

# %%
df1.head()
# Out:
# 1 Rk                Player  Nation Pos       Squad     Age  Born   90s   Att  \
# 2  1            Luis Abram  pe PER  DF     Granada  25-355  1996   6.2   220
# 3  2          Marcos Acuña  ar ARG  DF     Sevilla  30-112  1991  16.6  1319
# 4  3  Martin Agirregabiria  es ESP  DF      Alavés  25-283  1996  16.2   723
# 8  7          Joseph Aidoo  gh GHA  DF  Celta Vigo  26-141  1995  15.3   730
# 9  8          Carlos Akapo  gq EQG  DF       Cádiz  28-342  1993   9.6   345
#
# 1  Live  ... Right Head   TI Other   Cmp Off Out Int Blocks  Matches
# 2   211  ...    22   11    2     1   194   1   1   2      1  Matches
# 3  1095  ...   123   32  162     2  1050   2  21  39     32  Matches
# 4   548  ...   458   49  167     2   514   3  17  29     26  Matches
# 8   713  ...   526   52   10     3   606   0  20  14     11  Matches
# 9   259  ...   226   23   75     0   240   0  15   9     13  Matches
#
# [5 rows x 34 columns]

# %%
import seaborn as sns

# %%
df2 = df1.head(15).sort_values(by="Att", ascending=False)

plt.figure(figsize=(10, 6))
plt.barh(df2["Player"], df2["Att"], color="skyblue")
plt.xlabel("Total Passes")
plt.ylabel("Player")
plt.title("Total Passes by Players (Top 5 Defenders)")
# plt.gca().invert_yaxis()  # Invert the y-axis to display the highest value at the top
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.bar(df['Player'], df['90s'], color='lightcoral')
plt.xlabel('Player')
plt.ylabel('90s Played')
plt.title('90s Played by Players')
plt.xticks(rotation=90)
plt.show()

# %%
df1.columns
# Out:
# Index(['Rk', 'Player', 'Nation', 'Pos', 'Squad', 'Age', 'Born', '90s', 'Att',
#        'Live', 'Dead', 'FK', 'TB', 'Press', 'Sw', 'Crs', 'CK', 'In', 'Out',
#        'Str', 'Ground', 'Low', 'High', 'Left', 'Right', 'Head', 'TI', 'Other',
#        'Cmp', 'Off', 'Out', 'Int', 'Blocks', 'Matches'],
#       dtype='object', name=1)
